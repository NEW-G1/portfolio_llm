# %% [markdown]
# <h3>Flowise AI + Render 배포 </h3>
#
#
#
# 1. Github 로그인
#
# 2. flowise ai hub에 접속
# https://github.com/FlowiseAI/Flowise
#
# 3. FORK Repository
# ![image.png](attachment:image.png)
# Create New Fork
#
# 4. Join Render - Github로 가입
# https://dashboard.render.com/
#
# 5. Web Service 생성
#
# ![image-2.png](attachment:image-2.png)
#
# 6. Github Repository 로 배포
# ![image-3.png](attachment:image-3.png)
#
# 7. Flowise AI 를 포크한 레포지토리 선택
# ![image-4.png](attachment:image-4.png)
#
# 8. Node Runtime 기반으로 배포 - 금액은 Freetier (테스트용)
# ![image-5.png](attachment:image-5.png)
#
# 8-1. ID / PW 변수 추가 Advanced - Valiable 추가
#
# FLOWISE_USERNAME : admin
#
# FLOWISE_PASSWORD : ...
# ![image-8.png](attachment:image-8.png)
#
#
# 9. Create 후 Static 확인 -> Deployed 상태인지 확인
# ![image-6.png](attachment:image-6.png)
#
# 10. 웹서비스링크 확인
#
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# <Render 요금표>
#
# ![image.png](attachment:image.png)
